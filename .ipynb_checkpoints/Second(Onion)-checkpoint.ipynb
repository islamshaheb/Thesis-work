# %%
import pandas as pd
data = pd.read_csv('oniono.csv',parse_dates=["arrival_date"],index_col="arrival_date")

# %%
data.head(11+2)
# Out:
#                        state district   market commodity variety  min_price  \
# arrival_date
# 2020-03-01    Andhra Pradesh  Kurnool  Kurnool     Onion   Local       1350
# 2020-04-01    Andhra Pradesh  Kurnool  Kurnool     Onion   Local       1390
# 2020-06-01    Andhra Pradesh  Kurnool  Kurnool     Onion   Local       1460
# 2020-07-01    Andhra Pradesh  Kurnool  Kurnool     Onion   Local       2010
# 2020-10-01    Andhra Pradesh  Kurnool  Kurnool     Onion   Local       1320
# 2020-11-01    Andhra Pradesh  Kurnool  Kurnool     Onion   Local       1060
# 2020-01-13    Andhra Pradesh  Kurnool  Kurnool     Onion   Local       1200
# 2020-01-17    Andhra Pradesh  Kurnool  Kurnool     Onion   Local       1290
# 2020-01-18    Andhra Pradesh  Kurnool  Kurnool     Onion   Local       1770
# 2020-01-20    Andhra Pradesh  Kurnool  Kurnool     Onion   Local       2100
# 2020-01-21    Andhra Pradesh  Kurnool  Kurnool     Onion   Local       1870
# ...

# %%
fig, ax = plt.subplots()
ax.plot(data.index, data["min_price"],color='blue')
ax.set_xlabel('Time')
ax.set_ylabel('CO2 (ppm)', color='blue')
ax.tick_params('y', colors='blue')
ax2 = ax.twinx()
ax2.plot(data.index,data["max_price"],color='red')
ax2.set_ylabel('Relative temperature (Celsius)',color='red')
ax2.tick_params('y', colors='red')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-0661b18818f5> in <module>
# ----> 1 fig, ax = plt.subplots()
#       2 ax.plot(data.index, data["min_price"],color='blue')
#       3 ax.set_xlabel('Time')
#       4 ax.set_ylabel('CO2 (ppm)', color='blue')
#       5 ax.tick_params('y', colors='blue')
#
# NameError: name 'plt' is not defined

# %%
fig, ax = plt.subplots()
ax.plot(sixty_nine.index, sixty_nine['district'])
ax.set_xlabel('Time')
ax.set_ylabel('CO2 (ppm)')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-16-ac8ac1e48770> in <module>
# ----> 1 sixty_nine = data["2020-01-19":"2020-03-01"]
#
# c:\python3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3005             # either we have a slice or we have a string that can be converted
#    3006             #  to a slice for partial-string date indexing
# -> 3007             return self._slice(indexer, axis=0)
#    3008
#    3009         # Do we have a (boolean) DataFrame?
#
# c:\python3\lib\site-packages\pandas\core\generic.py in _slice(self, slobj, axis)
#    3806         Slicing with this method is *always* positional.
#    3807         """
# -> 3808         assert isinstance(slobj, slice), type(slobj)
#    3809         axis = self._get_block_manager_axis(axis)
#    3810         result = self._constructor(self._mgr.get_slice(slobj, axis=axis))
#
# ...

# %%
sixty_nine = data["2020-01-16":"2020-07-01"]
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-32-3798d9699bb2> in <module>
# ----> 1 sixty_nine = data["2020-01-16":"2020-07-01"]
#
# c:\python3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3005             # either we have a slice or we have a string that can be converted
#    3006             #  to a slice for partial-string date indexing
# -> 3007             return self._slice(indexer, axis=0)
#    3008
#    3009         # Do we have a (boolean) DataFrame?
#
# c:\python3\lib\site-packages\pandas\core\generic.py in _slice(self, slobj, axis)
#    3806         Slicing with this method is *always* positional.
#    3807         """
# -> 3808         assert isinstance(slobj, slice), type(slobj)
#    3809         axis = self._get_block_manager_axis(axis)
#    3810         result = self._constructor(self._mgr.get_slice(slobj, axis=axis))
#
# ...

# %%
data.index
# Out:
# DatetimeIndex(['2020-03-01', '2020-04-01', '2020-06-01', '2020-07-01',
#                '2020-10-01', '2020-11-01', '2020-01-13', '2020-01-17',
#                '2020-01-18', '2020-01-20',
#                ...
#                '2020-07-01', '2020-08-01', '2020-09-01', '2020-10-01',
#                '2020-11-01', '2020-12-01', '2020-01-13', '2020-01-14',
#                '2020-01-15', '2020-01-16'],
#               dtype='datetime64[ns]', name='arrival_date', length=182, freq=None)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.plot(data.district, data['max_price'], linestyle="None",marker="v",color='r')
ax.set_xlabel('Time')
ax.set_ylabel('max_price')
plt.rcParams["figure.figsize"]=10,3
plt.show()

# %%
data
# Out:
#                        state    district                     market commodity  \
# arrival_date
# 2020-01-25    Andhra Pradesh     Kurnool                    Kurnool     Onion
# 2020-01-27    Andhra Pradesh     Kurnool                    Kurnool     Onion
# 2020-01-28    Andhra Pradesh     Kurnool                    Kurnool     Onion
# 2020-01-29    Andhra Pradesh     Kurnool                    Kurnool     Onion
# 2020-01-16       Chattisgarh    Bilaspur                     Tiphra     Onion
# 2020-01-17       Chattisgarh    Bilaspur                     Tiphra     Onion
# 2020-01-18       Chattisgarh    Bilaspur                     Tiphra     Onion
# 2020-01-19       Chattisgarh    Bilaspur                     Tiphra     Onion
# 2020-11-03           Haryana     Panipat                   Madlauda     Onion
# 2020-12-03           Haryana     Panipat                   Madlauda     Onion
# 2020-03-13           Haryana     Panipat                   Madlauda     Onion
# ...

# %%
data
# Out:
#                        state    district                     market commodity  \
# arrival_date
# 2020-01-25    Andhra Pradesh     Kurnool                    Kurnool     Onion
# 2020-01-27    Andhra Pradesh     Kurnool                    Kurnool     Onion
# 2020-01-28    Andhra Pradesh     Kurnool                    Kurnool     Onion
# 2020-01-29    Andhra Pradesh     Kurnool                    Kurnool     Onion
# 2020-01-16       Chattisgarh    Bilaspur                     Tiphra     Onion
# 2020-01-17       Chattisgarh    Bilaspur                     Tiphra     Onion
# 2020-01-18       Chattisgarh    Bilaspur                     Tiphra     Onion
# 2020-01-19       Chattisgarh    Bilaspur                     Tiphra     Onion
# 2020-11-03           Haryana     Panipat                   Madlauda     Onion
# 2020-12-03           Haryana     Panipat                   Madlauda     Onion
# 2020-03-13           Haryana     Panipat                   Madlauda     Onion
# ...
